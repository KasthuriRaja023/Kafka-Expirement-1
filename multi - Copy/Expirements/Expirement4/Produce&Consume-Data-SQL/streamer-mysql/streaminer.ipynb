# %%
from kafka.admin import KafkaAdminClient, NewTopic

def create_topic(topic_name, num_partitions, replication_factor):
    admin_client = KafkaAdminClient(
        bootstrap_servers=['localhost:29092', 'localhost:29093'],
        client_id='test_client'
    )
    
    topic_list = []
    topic_list.append(NewTopic(name=topic_name, num_partitions=num_partitions, replication_factor=replication_factor))
    admin_client.create_topics(new_topics=topic_list, validate_only=False)

    admin_client.close()
    print(f"Topic '{topic_name}' created successfully.")

if __name__ == "__main__":
    create_topic("my_topic1", 1, 1)
# Out:
# Topic 'my_topic1' created successfully.

# %%
from kafka.admin import KafkaAdminClient, ConfigResource, ConfigResourceType
from kafka.errors import KafkaError

bootstrap_servers=['localhost:29092', 'localhost:29093'] #multibroker
#bootstrap_servers='localhost:9092' #single Broker


# Listing Topics
def list_topics(bootstrap_servers):
   try:
       admin_client = KafkaAdminClient(bootstrap_servers=bootstrap_servers)
       topics = admin_client.list_topics()
       admin_client.close()
       return topics
   except KafkaError as e:
       print(f"Failed to list topics: {e}")
       return []
   
list_topics(bootstrap_servers)
# Out:
# ['test',
#  'test12345',
#  'my_topic',
#  '__consumer_offsets',
#  'testjava',
#  'test12',
#  'csvdata']

# %%
# Deleting Topics
def delete_topic(bootstrap_servers, topic_name):
   try:
       admin_client = KafkaAdminClient(bootstrap_servers=bootstrap_servers)
       admin_client.delete_topics([topic_name])
       admin_client.close()
       print(f"Topic '{topic_name}' deleted.")
   except KafkaError as e:
       print(f"Failed to delete topic: {e}")


# Usage
bootstrap_servers=['localhost:29092', 'localhost:29093'] #multibroker
#bootstrap_servers='localhost:9092' #single Broker

topic_name="my_topic1"
# Delete Topic
delete_topic(bootstrap_servers, topic_name)
# Out:
# Topic 'my_topic1' deleted.

# %%
from kafka.admin import KafkaAdminClient, ConfigResource, ConfigResourceType
from kafka.errors import KafkaError


def modify_topic_config(bootstrap_servers, topic_name, config_updates):
   try:
       admin_client = KafkaAdminClient(bootstrap_servers=bootstrap_servers)
       topics = admin_client.list_topics()
       if topic_name not in topics:
           print(f"Topic '{topic_name}' does not exist.")
           return
      
       config_resource = ConfigResource(ConfigResourceType.TOPIC, topic_name, configs=config_updates)
      
       admin_client.alter_configs([config_resource])
       admin_client.close()
       print(f"Configuration for topic '{topic_name}' updated.")
   except KafkaError as e:
       print(f"Failed to modify topic configuration: {e}")
       
# Usage
if __name__ == "__main__":
   bootstrap_servers = ['localhost:29092', 'localhost:29093']
   topic_name = 'csvdata'
   config_updates = {
   'retention.ms': '86400000',  # Retain messages for 1 day
   'cleanup.policy': 'compact',  # Enable log compaction
   'segment.ms': '604800000',  # Roll log segments every 1 week
   'segment.bytes': '1073741824',  # Roll log segments at 1 GB
   'max.message.bytes': '2000000'  # Set max message size to 2 MB
}


modify_topic_config(bootstrap_servers, topic_name, config_updates)
# Out:
# Configuration for topic 'csvdata' updated.

# %% [markdown]
# Streaming

# %%
from kafka import KafkaProducer
import csv
import json
from kafka.errors import KafkaError

def read_csv(file_path):
    with open(file_path, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            yield row

def on_send_success(record_metadata):
    print(f'Message successfully sent to topic {record_metadata.topic} partition {record_metadata.partition} offset {record_metadata.offset}')

def on_send_error(excp):
    print(f'I am an error callback: {excp}')
    # Handle the exception

def main():
    producer = KafkaProducer(
        bootstrap_servers = ['localhost:29092', 'localhost:29093'], #For Multi Brooker Cluster
        # bootstrap_servers = 'localhost:9092', #For Single Broker Cluster
        value_serializer=lambda v: json.dumps(v).encode('utf-8')
    )
    
    for data in read_csv('sample_data.csv'):
        producer.send('my_topic', value=data).add_callback(on_send_success).add_errback(on_send_error)
        
    producer.flush()
    producer.close()

if __name__ == '__main__':
    main()
# Out:
# Message successfully sent to topic my_topic partition 0 offset 0
# Message successfully sent to topic my_topic partition 0 offset 1
# Message successfully sent to topic my_topic partition 0 offset 2
# Message successfully sent to topic my_topic partition 0 offset 3
# Message successfully sent to topic my_topic partition 0 offset 4
# Message successfully sent to topic my_topic partition 0 offset 5
# Message successfully sent to topic my_topic partition 0 offset 6
# Message successfully sent to topic my_topic partition 0 offset 7
# Message successfully sent to topic my_topic partition 0 offset 8
# Message successfully sent to topic my_topic partition 0 offset 9
# Message successfully sent to topic my_topic partition 0 offset 10
# Message successfully sent to topic my_topic partition 0 offset 11
# Message successfully sent to topic my_topic partition 0 offset 12
# Message successfully sent to topic my_topic partition 0 offset 13
# Message successfully sent to topic my_topic partition 0 offset 14
# Message successfully sent to topic my_topic partition 0 offset 15
# Message successfully sent to topic my_topic partition 0 offset 16
# Message successfully sent to topic my_topic partition 0 offset 17
# Message successfully sent to topic my_topic partition 0 offset 18
# Message successfully sent to topic my_topic partition 0 offset 19
# Message successfully sent to topic my_topic partition 0 offset 20
# Message successfully sent to topic my_topic partition 0 offset 21
# Message successfully sent to topic my_topic partition 0 offset 22
# Message successfully sent to topic my_topic partition 0 offset 23
# Message successfully sent to topic my_topic partition 0 offset 24
# Message successfully sent to topic my_topic partition 0 offset 25
# Message successfully sent to topic my_topic partition 0 offset 26
# Message successfully sent to topic my_topic partition 0 offset 27
# Message successfully sent to topic my_topic partition 0 offset 28
# Message successfully sent to topic my_topic partition 0 offset 29
# Message successfully sent to topic my_topic partition 0 offset 30
# Message successfully sent to topic my_topic partition 0 offset 31
# Message successfully sent to topic my_topic partition 0 offset 32
# Message successfully sent to topic my_topic partition 0 offset 33
# Message successfully sent to topic my_topic partition 0 offset 34
# Message successfully sent to topic my_topic partition 0 offset 35
# Message successfully sent to topic my_topic partition 0 offset 36
# Message successfully sent to topic my_topic partition 0 offset 37
# Message successfully sent to topic my_topic partition 0 offset 38
# Message successfully sent to topic my_topic partition 0 offset 39
# Message successfully sent to topic my_topic partition 0 offset 40
# Message successfully sent to topic my_topic partition 0 offset 41
# Message successfully sent to topic my_topic partition 0 offset 42
# Message successfully sent to topic my_topic partition 0 offset 43
# Message successfully sent to topic my_topic partition 0 offset 44
# Message successfully sent to topic my_topic partition 0 offset 45
# Message successfully sent to topic my_topic partition 0 offset 46
# Message successfully sent to topic my_topic partition 0 offset 47
# Message successfully sent to topic my_topic partition 0 offset 48
# Message successfully sent to topic my_topic partition 0 offset 49
# Message successfully sent to topic my_topic partition 0 offset 50
# Message successfully sent to topic my_topic partition 0 offset 51
# Message successfully sent to topic my_topic partition 0 offset 52
# Message successfully sent to topic my_topic partition 0 offset 53
# Message successfully sent to topic my_topic partition 0 offset 54
# Message successfully sent to topic my_topic partition 0 offset 55
# Message successfully sent to topic my_topic partition 0 offset 56
# Message successfully sent to topic my_topic partition 0 offset 57
# Message successfully sent to topic my_topic partition 0 offset 58
# Message successfully sent to topic my_topic partition 0 offset 59
# Message successfully sent to topic my_topic partition 0 offset 60
# Message successfully sent to topic my_topic partition 0 offset 61
# Message successfully sent to topic my_topic partition 0 offset 62
# Message successfully sent to topic my_topic partition 0 offset 63
# Message successfully sent to topic my_topic partition 0 offset 64
# Message successfully sent to topic my_topic partition 0 offset 65
# Message successfully sent to topic my_topic partition 0 offset 66
# Message successfully sent to topic my_topic partition 0 offset 67
# Message successfully sent to topic my_topic partition 0 offset 68
# Message successfully sent to topic my_topic partition 0 offset 69
# Message successfully sent to topic my_topic partition 0 offset 70
# Message successfully sent to topic my_topic partition 0 offset 71
# Message successfully sent to topic my_topic partition 0 offset 72
# Message successfully sent to topic my_topic partition 0 offset 73
# Message successfully sent to topic my_topic partition 0 offset 74
# Message successfully sent to topic my_topic partition 0 offset 75
# Message successfully sent to topic my_topic partition 0 offset 76
# Message successfully sent to topic my_topic partition 0 offset 77
# Message successfully sent to topic my_topic partition 0 offset 78
# Message successfully sent to topic my_topic partition 0 offset 79
# Message successfully sent to topic my_topic partition 0 offset 80
# Message successfully sent to topic my_topic partition 0 offset 81
# Message successfully sent to topic my_topic partition 0 offset 82
# Message successfully sent to topic my_topic partition 0 offset 83
# Message successfully sent to topic my_topic partition 0 offset 84
# Message successfully sent to topic my_topic partition 0 offset 85
# Message successfully sent to topic my_topic partition 0 offset 86
# Message successfully sent to topic my_topic partition 0 offset 87
# Message successfully sent to topic my_topic partition 0 offset 88
# Message successfully sent to topic my_topic partition 0 offset 89
# Message successfully sent to topic my_topic partition 0 offset 90
# Message successfully sent to topic my_topic partition 0 offset 91
# Message successfully sent to topic my_topic partition 0 offset 92
# Message successfully sent to topic my_topic partition 0 offset 93
# Message successfully sent to topic my_topic partition 0 offset 94
# Message successfully sent to topic my_topic partition 0 offset 95
# Message successfully sent to topic my_topic partition 0 offset 96
# Message successfully sent to topic my_topic partition 0 offset 97
# Message successfully sent to topic my_topic partition 0 offset 98
# Message successfully sent to topic my_topic partition 0 offset 99

# %%
from kafka import KafkaConsumer
import json
import mysql.connector
from mysql.connector import Error

def insert_into_db(data):
    try:
        conn = mysql.connector.connect(
        host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
        port = 4000,
        user = "3PTDVomKhQVBrZJ.root",
        password = "1ykHI1dKoeNvSlY4",
        database = "kafka",
        )
        cursor = conn.cursor()
        
        add_data = ("INSERT INTO your_table "
                    "(id, name, age, city) "
                    "VALUES (%s, %s, %s, %s)")
        
        data_tuple = (data['id'], data['name'], data['age'], data['city'])
        cursor.execute(add_data, data_tuple)
        
        conn.commit()
        print(f"Inserted data: {data}")
    except Error as e:
        print(f"Error: {e}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

def main():
    print("Starting Kafka consumer...")
    consumer = KafkaConsumer(
        'my_topic',
        bootstrap_servers = ['localhost:29092', 'localhost:29093'],
        auto_offset_reset='earliest',
        enable_auto_commit=True,
        group_id='my_group',
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        consumer_timeout_ms=10000  # Timeout after 10 seconds if no message is received
    )
    
    for message in consumer:
        data = message.value
        print(f"Received data: {data}")
        insert_into_db(data)
    
    print("No more messages in the topic or consumer timed out.")
    consumer.close()

if __name__ == '__main__':
    main()
# Out:
# Starting Kafka consumer...
# Received data: {'id': '1', 'name': 'Person 1', 'age': '21', 'city': 'City 1'}
# Inserted data: {'id': '1', 'name': 'Person 1', 'age': '21', 'city': 'City 1'}
# Received data: {'id': '2', 'name': 'Person 2', 'age': '22', 'city': 'City 2'}
# Inserted data: {'id': '2', 'name': 'Person 2', 'age': '22', 'city': 'City 2'}
# Received data: {'id': '3', 'name': 'Person 3', 'age': '23', 'city': 'City 3'}
# Inserted data: {'id': '3', 'name': 'Person 3', 'age': '23', 'city': 'City 3'}
# Received data: {'id': '4', 'name': 'Person 4', 'age': '24', 'city': 'City 4'}
# Inserted data: {'id': '4', 'name': 'Person 4', 'age': '24', 'city': 'City 4'}
# Received data: {'id': '5', 'name': 'Person 5', 'age': '25', 'city': 'City 5'}
# Inserted data: {'id': '5', 'name': 'Person 5', 'age': '25', 'city': 'City 5'}
# Received data: {'id': '6', 'name': 'Person 6', 'age': '26', 'city': 'City 6'}
# Inserted data: {'id': '6', 'name': 'Person 6', 'age': '26', 'city': 'City 6'}
# Received data: {'id': '7', 'name': 'Person 7', 'age': '27', 'city': 'City 7'}
# Inserted data: {'id': '7', 'name': 'Person 7', 'age': '27', 'city': 'City 7'}
# Received data: {'id': '8', 'name': 'Person 8', 'age': '28', 'city': 'City 8'}
# Inserted data: {'id': '8', 'name': 'Person 8', 'age': '28', 'city': 'City 8'}
# Received data: {'id': '9', 'name': 'Person 9', 'age': '29', 'city': 'City 9'}
# Inserted data: {'id': '9', 'name': 'Person 9', 'age': '29', 'city': 'City 9'}
# Received data: {'id': '10', 'name': 'Person 10', 'age': '30', 'city': 'City 0'}
# Inserted data: {'id': '10', 'name': 'Person 10', 'age': '30', 'city': 'City 0'}
# Received data: {'id': '11', 'name': 'Person 11', 'age': '31', 'city': 'City 1'}
# Inserted data: {'id': '11', 'name': 'Person 11', 'age': '31', 'city': 'City 1'}
# Received data: {'id': '12', 'name': 'Person 12', 'age': '32', 'city': 'City 2'}
# Inserted data: {'id': '12', 'name': 'Person 12', 'age': '32', 'city': 'City 2'}
# Received data: {'id': '13', 'name': 'Person 13', 'age': '33', 'city': 'City 3'}
# Inserted data: {'id': '13', 'name': 'Person 13', 'age': '33', 'city': 'City 3'}
# Received data: {'id': '14', 'name': 'Person 14', 'age': '34', 'city': 'City 4'}
# Inserted data: {'id': '14', 'name': 'Person 14', 'age': '34', 'city': 'City 4'}
# Received data: {'id': '15', 'name': 'Person 15', 'age': '35', 'city': 'City 5'}
# Inserted data: {'id': '15', 'name': 'Person 15', 'age': '35', 'city': 'City 5'}
# Received data: {'id': '16', 'name': 'Person 16', 'age': '36', 'city': 'City 6'}
# Inserted data: {'id': '16', 'name': 'Person 16', 'age': '36', 'city': 'City 6'}
# Received data: {'id': '17', 'name': 'Person 17', 'age': '37', 'city': 'City 7'}
# Inserted data: {'id': '17', 'name': 'Person 17', 'age': '37', 'city': 'City 7'}
# Received data: {'id': '18', 'name': 'Person 18', 'age': '38', 'city': 'City 8'}
# Inserted data: {'id': '18', 'name': 'Person 18', 'age': '38', 'city': 'City 8'}
# Received data: {'id': '19', 'name': 'Person 19', 'age': '39', 'city': 'City 9'}
# Inserted data: {'id': '19', 'name': 'Person 19', 'age': '39', 'city': 'City 9'}
# Received data: {'id': '20', 'name': 'Person 20', 'age': '40', 'city': 'City 0'}
# Inserted data: {'id': '20', 'name': 'Person 20', 'age': '40', 'city': 'City 0'}
# Received data: {'id': '21', 'name': 'Person 21', 'age': '21', 'city': 'City 1'}
# Inserted data: {'id': '21', 'name': 'Person 21', 'age': '21', 'city': 'City 1'}
# Received data: {'id': '22', 'name': 'Person 22', 'age': '22', 'city': 'City 2'}
# Inserted data: {'id': '22', 'name': 'Person 22', 'age': '22', 'city': 'City 2'}
# Received data: {'id': '23', 'name': 'Person 23', 'age': '23', 'city': 'City 3'}
# Inserted data: {'id': '23', 'name': 'Person 23', 'age': '23', 'city': 'City 3'}
# Received data: {'id': '24', 'name': 'Person 24', 'age': '24', 'city': 'City 4'}
# Inserted data: {'id': '24', 'name': 'Person 24', 'age': '24', 'city': 'City 4'}
# Received data: {'id': '25', 'name': 'Person 25', 'age': '25', 'city': 'City 5'}
# Inserted data: {'id': '25', 'name': 'Person 25', 'age': '25', 'city': 'City 5'}
# Received data: {'id': '26', 'name': 'Person 26', 'age': '26', 'city': 'City 6'}
# Inserted data: {'id': '26', 'name': 'Person 26', 'age': '26', 'city': 'City 6'}
# Received data: {'id': '27', 'name': 'Person 27', 'age': '27', 'city': 'City 7'}
# Inserted data: {'id': '27', 'name': 'Person 27', 'age': '27', 'city': 'City 7'}
# Received data: {'id': '28', 'name': 'Person 28', 'age': '28', 'city': 'City 8'}
# Inserted data: {'id': '28', 'name': 'Person 28', 'age': '28', 'city': 'City 8'}
# Received data: {'id': '29', 'name': 'Person 29', 'age': '29', 'city': 'City 9'}
# Inserted data: {'id': '29', 'name': 'Person 29', 'age': '29', 'city': 'City 9'}
# Received data: {'id': '30', 'name': 'Person 30', 'age': '30', 'city': 'City 0'}
# Inserted data: {'id': '30', 'name': 'Person 30', 'age': '30', 'city': 'City 0'}
# Received data: {'id': '31', 'name': 'Person 31', 'age': '31', 'city': 'City 1'}
# Inserted data: {'id': '31', 'name': 'Person 31', 'age': '31', 'city': 'City 1'}
# Received data: {'id': '32', 'name': 'Person 32', 'age': '32', 'city': 'City 2'}
# Inserted data: {'id': '32', 'name': 'Person 32', 'age': '32', 'city': 'City 2'}
# Received data: {'id': '33', 'name': 'Person 33', 'age': '33', 'city': 'City 3'}
# Inserted data: {'id': '33', 'name': 'Person 33', 'age': '33', 'city': 'City 3'}
# Received data: {'id': '34', 'name': 'Person 34', 'age': '34', 'city': 'City 4'}
# Inserted data: {'id': '34', 'name': 'Person 34', 'age': '34', 'city': 'City 4'}
# Received data: {'id': '35', 'name': 'Person 35', 'age': '35', 'city': 'City 5'}
# Inserted data: {'id': '35', 'name': 'Person 35', 'age': '35', 'city': 'City 5'}
# Received data: {'id': '36', 'name': 'Person 36', 'age': '36', 'city': 'City 6'}
# Inserted data: {'id': '36', 'name': 'Person 36', 'age': '36', 'city': 'City 6'}
# Received data: {'id': '37', 'name': 'Person 37', 'age': '37', 'city': 'City 7'}
# Inserted data: {'id': '37', 'name': 'Person 37', 'age': '37', 'city': 'City 7'}
# Received data: {'id': '38', 'name': 'Person 38', 'age': '38', 'city': 'City 8'}
# Inserted data: {'id': '38', 'name': 'Person 38', 'age': '38', 'city': 'City 8'}
# Received data: {'id': '39', 'name': 'Person 39', 'age': '39', 'city': 'City 9'}
# Inserted data: {'id': '39', 'name': 'Person 39', 'age': '39', 'city': 'City 9'}
# Received data: {'id': '40', 'name': 'Person 40', 'age': '40', 'city': 'City 0'}
# Inserted data: {'id': '40', 'name': 'Person 40', 'age': '40', 'city': 'City 0'}
# Received data: {'id': '41', 'name': 'Person 41', 'age': '21', 'city': 'City 1'}
# Inserted data: {'id': '41', 'name': 'Person 41', 'age': '21', 'city': 'City 1'}
# Received data: {'id': '42', 'name': 'Person 42', 'age': '22', 'city': 'City 2'}
# Inserted data: {'id': '42', 'name': 'Person 42', 'age': '22', 'city': 'City 2'}
# Received data: {'id': '43', 'name': 'Person 43', 'age': '23', 'city': 'City 3'}
# Inserted data: {'id': '43', 'name': 'Person 43', 'age': '23', 'city': 'City 3'}
# Received data: {'id': '44', 'name': 'Person 44', 'age': '24', 'city': 'City 4'}
# Inserted data: {'id': '44', 'name': 'Person 44', 'age': '24', 'city': 'City 4'}
# Received data: {'id': '45', 'name': 'Person 45', 'age': '25', 'city': 'City 5'}
# Inserted data: {'id': '45', 'name': 'Person 45', 'age': '25', 'city': 'City 5'}
# Received data: {'id': '46', 'name': 'Person 46', 'age': '26', 'city': 'City 6'}
# Inserted data: {'id': '46', 'name': 'Person 46', 'age': '26', 'city': 'City 6'}
# Received data: {'id': '47', 'name': 'Person 47', 'age': '27', 'city': 'City 7'}
# Inserted data: {'id': '47', 'name': 'Person 47', 'age': '27', 'city': 'City 7'}
# Received data: {'id': '48', 'name': 'Person 48', 'age': '28', 'city': 'City 8'}
# Inserted data: {'id': '48', 'name': 'Person 48', 'age': '28', 'city': 'City 8'}
# Received data: {'id': '49', 'name': 'Person 49', 'age': '29', 'city': 'City 9'}
# Inserted data: {'id': '49', 'name': 'Person 49', 'age': '29', 'city': 'City 9'}
# Received data: {'id': '50', 'name': 'Person 50', 'age': '30', 'city': 'City 0'}
# Inserted data: {'id': '50', 'name': 'Person 50', 'age': '30', 'city': 'City 0'}
# Received data: {'id': '51', 'name': 'Person 51', 'age': '31', 'city': 'City 1'}
# Inserted data: {'id': '51', 'name': 'Person 51', 'age': '31', 'city': 'City 1'}
# Received data: {'id': '52', 'name': 'Person 52', 'age': '32', 'city': 'City 2'}
# Inserted data: {'id': '52', 'name': 'Person 52', 'age': '32', 'city': 'City 2'}
# Received data: {'id': '53', 'name': 'Person 53', 'age': '33', 'city': 'City 3'}
# Inserted data: {'id': '53', 'name': 'Person 53', 'age': '33', 'city': 'City 3'}
# Received data: {'id': '54', 'name': 'Person 54', 'age': '34', 'city': 'City 4'}
# Inserted data: {'id': '54', 'name': 'Person 54', 'age': '34', 'city': 'City 4'}
# Received data: {'id': '55', 'name': 'Person 55', 'age': '35', 'city': 'City 5'}
# Inserted data: {'id': '55', 'name': 'Person 55', 'age': '35', 'city': 'City 5'}
# Received data: {'id': '56', 'name': 'Person 56', 'age': '36', 'city': 'City 6'}
# Inserted data: {'id': '56', 'name': 'Person 56', 'age': '36', 'city': 'City 6'}
# Received data: {'id': '57', 'name': 'Person 57', 'age': '37', 'city': 'City 7'}
# Inserted data: {'id': '57', 'name': 'Person 57', 'age': '37', 'city': 'City 7'}
# Received data: {'id': '58', 'name': 'Person 58', 'age': '38', 'city': 'City 8'}
# Inserted data: {'id': '58', 'name': 'Person 58', 'age': '38', 'city': 'City 8'}
# Received data: {'id': '59', 'name': 'Person 59', 'age': '39', 'city': 'City 9'}
# Inserted data: {'id': '59', 'name': 'Person 59', 'age': '39', 'city': 'City 9'}
# Received data: {'id': '60', 'name': 'Person 60', 'age': '40', 'city': 'City 0'}
# Inserted data: {'id': '60', 'name': 'Person 60', 'age': '40', 'city': 'City 0'}
# Received data: {'id': '61', 'name': 'Person 61', 'age': '21', 'city': 'City 1'}
# Inserted data: {'id': '61', 'name': 'Person 61', 'age': '21', 'city': 'City 1'}
# Received data: {'id': '62', 'name': 'Person 62', 'age': '22', 'city': 'City 2'}
# Inserted data: {'id': '62', 'name': 'Person 62', 'age': '22', 'city': 'City 2'}
# Received data: {'id': '63', 'name': 'Person 63', 'age': '23', 'city': 'City 3'}
# Inserted data: {'id': '63', 'name': 'Person 63', 'age': '23', 'city': 'City 3'}
# Received data: {'id': '64', 'name': 'Person 64', 'age': '24', 'city': 'City 4'}
# Inserted data: {'id': '64', 'name': 'Person 64', 'age': '24', 'city': 'City 4'}
# Received data: {'id': '65', 'name': 'Person 65', 'age': '25', 'city': 'City 5'}
# Inserted data: {'id': '65', 'name': 'Person 65', 'age': '25', 'city': 'City 5'}
# Received data: {'id': '66', 'name': 'Person 66', 'age': '26', 'city': 'City 6'}
# Inserted data: {'id': '66', 'name': 'Person 66', 'age': '26', 'city': 'City 6'}
# Received data: {'id': '67', 'name': 'Person 67', 'age': '27', 'city': 'City 7'}
# Inserted data: {'id': '67', 'name': 'Person 67', 'age': '27', 'city': 'City 7'}
# Received data: {'id': '68', 'name': 'Person 68', 'age': '28', 'city': 'City 8'}
# Inserted data: {'id': '68', 'name': 'Person 68', 'age': '28', 'city': 'City 8'}
# Received data: {'id': '69', 'name': 'Person 69', 'age': '29', 'city': 'City 9'}
# Inserted data: {'id': '69', 'name': 'Person 69', 'age': '29', 'city': 'City 9'}
# Received data: {'id': '70', 'name': 'Person 70', 'age': '30', 'city': 'City 0'}
# Inserted data: {'id': '70', 'name': 'Person 70', 'age': '30', 'city': 'City 0'}
# Received data: {'id': '71', 'name': 'Person 71', 'age': '31', 'city': 'City 1'}
# Inserted data: {'id': '71', 'name': 'Person 71', 'age': '31', 'city': 'City 1'}
# Received data: {'id': '72', 'name': 'Person 72', 'age': '32', 'city': 'City 2'}
# Inserted data: {'id': '72', 'name': 'Person 72', 'age': '32', 'city': 'City 2'}
# Received data: {'id': '73', 'name': 'Person 73', 'age': '33', 'city': 'City 3'}
# Inserted data: {'id': '73', 'name': 'Person 73', 'age': '33', 'city': 'City 3'}
# Received data: {'id': '74', 'name': 'Person 74', 'age': '34', 'city': 'City 4'}
# Inserted data: {'id': '74', 'name': 'Person 74', 'age': '34', 'city': 'City 4'}
# Received data: {'id': '75', 'name': 'Person 75', 'age': '35', 'city': 'City 5'}
# Inserted data: {'id': '75', 'name': 'Person 75', 'age': '35', 'city': 'City 5'}
# Received data: {'id': '76', 'name': 'Person 76', 'age': '36', 'city': 'City 6'}
# Inserted data: {'id': '76', 'name': 'Person 76', 'age': '36', 'city': 'City 6'}
# Received data: {'id': '77', 'name': 'Person 77', 'age': '37', 'city': 'City 7'}
# Inserted data: {'id': '77', 'name': 'Person 77', 'age': '37', 'city': 'City 7'}
# Received data: {'id': '78', 'name': 'Person 78', 'age': '38', 'city': 'City 8'}
# Inserted data: {'id': '78', 'name': 'Person 78', 'age': '38', 'city': 'City 8'}
# Received data: {'id': '79', 'name': 'Person 79', 'age': '39', 'city': 'City 9'}
# Inserted data: {'id': '79', 'name': 'Person 79', 'age': '39', 'city': 'City 9'}
# Received data: {'id': '80', 'name': 'Person 80', 'age': '40', 'city': 'City 0'}
# Inserted data: {'id': '80', 'name': 'Person 80', 'age': '40', 'city': 'City 0'}
# Received data: {'id': '81', 'name': 'Person 81', 'age': '21', 'city': 'City 1'}
# Inserted data: {'id': '81', 'name': 'Person 81', 'age': '21', 'city': 'City 1'}
# Received data: {'id': '82', 'name': 'Person 82', 'age': '22', 'city': 'City 2'}
# Inserted data: {'id': '82', 'name': 'Person 82', 'age': '22', 'city': 'City 2'}
# Received data: {'id': '83', 'name': 'Person 83', 'age': '23', 'city': 'City 3'}
# Inserted data: {'id': '83', 'name': 'Person 83', 'age': '23', 'city': 'City 3'}
# Received data: {'id': '84', 'name': 'Person 84', 'age': '24', 'city': 'City 4'}
# Inserted data: {'id': '84', 'name': 'Person 84', 'age': '24', 'city': 'City 4'}
# Received data: {'id': '85', 'name': 'Person 85', 'age': '25', 'city': 'City 5'}
# Inserted data: {'id': '85', 'name': 'Person 85', 'age': '25', 'city': 'City 5'}
# Received data: {'id': '86', 'name': 'Person 86', 'age': '26', 'city': 'City 6'}
# Inserted data: {'id': '86', 'name': 'Person 86', 'age': '26', 'city': 'City 6'}
# Received data: {'id': '87', 'name': 'Person 87', 'age': '27', 'city': 'City 7'}
# Inserted data: {'id': '87', 'name': 'Person 87', 'age': '27', 'city': 'City 7'}
# Received data: {'id': '88', 'name': 'Person 88', 'age': '28', 'city': 'City 8'}
# Inserted data: {'id': '88', 'name': 'Person 88', 'age': '28', 'city': 'City 8'}
# Received data: {'id': '89', 'name': 'Person 89', 'age': '29', 'city': 'City 9'}
# Inserted data: {'id': '89', 'name': 'Person 89', 'age': '29', 'city': 'City 9'}
# Received data: {'id': '90', 'name': 'Person 90', 'age': '30', 'city': 'City 0'}
# Inserted data: {'id': '90', 'name': 'Person 90', 'age': '30', 'city': 'City 0'}
# Received data: {'id': '91', 'name': 'Person 91', 'age': '31', 'city': 'City 1'}
# Inserted data: {'id': '91', 'name': 'Person 91', 'age': '31', 'city': 'City 1'}
# Received data: {'id': '92', 'name': 'Person 92', 'age': '32', 'city': 'City 2'}
# Inserted data: {'id': '92', 'name': 'Person 92', 'age': '32', 'city': 'City 2'}
# Received data: {'id': '93', 'name': 'Person 93', 'age': '33', 'city': 'City 3'}
# Inserted data: {'id': '93', 'name': 'Person 93', 'age': '33', 'city': 'City 3'}
# Received data: {'id': '94', 'name': 'Person 94', 'age': '34', 'city': 'City 4'}
# Inserted data: {'id': '94', 'name': 'Person 94', 'age': '34', 'city': 'City 4'}
# Received data: {'id': '95', 'name': 'Person 95', 'age': '35', 'city': 'City 5'}
# Inserted data: {'id': '95', 'name': 'Person 95', 'age': '35', 'city': 'City 5'}
# Received data: {'id': '96', 'name': 'Person 96', 'age': '36', 'city': 'City 6'}
# Inserted data: {'id': '96', 'name': 'Person 96', 'age': '36', 'city': 'City 6'}
# Received data: {'id': '97', 'name': 'Person 97', 'age': '37', 'city': 'City 7'}
# Inserted data: {'id': '97', 'name': 'Person 97', 'age': '37', 'city': 'City 7'}
# Received data: {'id': '98', 'name': 'Person 98', 'age': '38', 'city': 'City 8'}
# Inserted data: {'id': '98', 'name': 'Person 98', 'age': '38', 'city': 'City 8'}
# Received data: {'id': '99', 'name': 'Person 99', 'age': '39', 'city': 'City 9'}
# Inserted data: {'id': '99', 'name': 'Person 99', 'age': '39', 'city': 'City 9'}
# Received data: {'id': '100', 'name': 'Person 100', 'age': '40', 'city': 'City 0'}
# Inserted data: {'id': '100', 'name': 'Person 100', 'age': '40', 'city': 'City 0'}
# No more messages in the topic or consumer timed out.
